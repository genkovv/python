# %% [markdown]
# # Visualisation practice

# %%
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
import warnings as warnings

# %% [markdown]
# ##### Disable all warnings and configure default seaborn graph size.

# %%
warnings.filterwarnings('ignore') 
sns.set(rc={'figure.figsize':(6,5)})

# %% [markdown]
# ##### The purpose of this workbook is to visualise and present correlations between variabled from iris dataset.

# %% [markdown]
# Import iris dataset from csv to iris dataframe.

# %%
iris=pd.read_csv("iris.csv")

# %% [markdown]
# ##### Present the columns and first 5 rows of iris dataset

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ##### Check column numbers, types and total number of rows.

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %% [markdown]
# ##### Ensure all columns do not have empty values "Nan".

# %%
iris.apply(axis=0, func=lambda x : any(pd.isnull(x)))
# Out:
# sepal_length    False
# sepal_width     False
# petal_length    False
# petal_width     False
# species         False
# dtype: bool

# %% [markdown]
# ##### Identify unique values in "species" column.

# %%
iris["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# ##### Identify Pearson correlation between float variables

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# ##### Based on above correlation matrix "petal_length" and "sepal_width" have negative correlation, however separating the spiecies in three matrices both variables do not have negative but positive correlation and below graph is showing inaccurate information.

# %%
sns.regplot(x="petal_length",y="sepal_width",data=iris)

# %% [markdown]
# ##### Present heatmap variable correlations using colours.

# %%
sns.heatmap(iris.corr())

# %% [markdown]
# ##### Plot pairwise relationships in a dataset.

# %%
sns.pairplot(iris)

# %%
sns.regplot(x="petal_width",y="sepal_length",data=iris)
pearson_corr,p_value=stats.pearsonr(iris["petal_width"],iris["sepal_length"])
print("Pearson r:",pearson_corr)
print("P-value:  ",p_valuestats)
# Out:
# Pearson r: 0.8179411262715754
# P-value:   2.325498079793358e-37

# %%
sns.distplot(iris["sepal_width"],hist=True,kde=False)

# %%
sns.scatterplot(x="petal_width",y="sepal_length",data=iris,hue="species")

# %%
sns.stripplot(x="species",y="petal_length",data=iris)

# %%
sns.set(rc={'figure.figsize':(25,13)})
sns.barplot(x="petal_length",y="petal_width",data=iris)

# %%
sns.set(rc={'figure.figsize':(8,8)})
sns.boxplot(data=iris)

# %% [markdown]
# ##### Create three different dataframes for each species to ensure data correlation is not skewed. For each dataframe check the highest correlation coefficient (excluding number 1) and create regression line between two of the variables

# %%
sns.set(rc={'figure.figsize':(6,5)})
iris_setosa=iris[iris["species"]=="setosa"]
iris_setosa.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000     0.742547      0.267176     0.278098
# sepal_width       0.742547     1.000000      0.177700     0.232752
# petal_length      0.267176     0.177700      1.000000     0.331630
# petal_width       0.278098     0.232752      0.331630     1.000000

# %%
sns.regplot(x="sepal_width",y="sepal_length",data=iris_setosa)

# %%
iris_versicolor=iris[iris["species"]=="versicolor"]
iris_versicolor.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000     0.525911      0.754049     0.546461
# sepal_width       0.525911     1.000000      0.560522     0.663999
# petal_length      0.754049     0.560522      1.000000     0.786668
# petal_width       0.546461     0.663999      0.786668     1.000000

# %%
sns.regplot(x="petal_length",y="sepal_length",data=iris_versicolor)

# %%
iris_virginica=iris[iris["species"]=="virginica"]
iris_virginica.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000     0.457228      0.864225     0.281108
# sepal_width       0.457228     1.000000      0.401045     0.537728
# petal_length      0.864225     0.401045      1.000000     0.322108
# petal_width       0.281108     0.537728      0.322108     1.000000

# %%
sns.regplot(x="petal_length",y="sepal_length",data=iris_virginica)
