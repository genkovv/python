# %% [markdown]
# # Association Rules
# ## What are Association Rules?
# Association Rules are a kind of rule-based machine learning.

# %% [markdown]
# ## Where did they come from?
# Association Rules were designed to discover relationships in large-scale transaction data recorded by point-of-sale (POS) systems in supermarkets. Data Scientists were looking for items that were commonly bought together so they could use data to offer customers better deals. For example, the rule: {onions, potatoes} > {burger} found in the sales data of a supermarket would indicate that if a customer buys onions and potatoes together, they are likely to also buy burgers.
#
# Association Rules have since been used to find relationships between any sequences of things. Examples include things like web analytics (how someone behaves on a website), intrusion detection in cybersecurity (strange series of behaviours might indicate a hack) and bioinformatics in healthcare.
#
# Association Rules are most commonly built using the Aprioriand Eclat algorithms. We're going to be using Apriori for this notebook exercise.

# %% [markdown]
# ## The Brief
# Using supermarket data, find products that are commonly brought together with a special interest in the sale of limes.

# %% [markdown]
# ## Import the required libraries
#
# You may need to install some using `pip install [package name]`

# %%
import numpy as np # linear algebra
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# ## Source & Store
#
# Download the instacart dataset and import it using read.csv. You'll need to read order_products__prior.csv and products.csv

# %%
order_products_prior = pd.read_csv("instacart/order_products__prior.csv", nrows=20000)
order_products_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
products = pd.read_csv("instacart/products.csv")
products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %% [markdown]
# ## Join the data
#
# The data is supplied pretty much exactly how instacart stored it in their database. We need to join the files together in order to get it into a usable state.
#
# Currently the `order_products__prior.csv` doesn't have any product names - it only has IDs - so we can map the product names to each product ID using the `products.csv` data.
#
# You'll learn more about how this is done in Sprint 4 when we look at SQL. For now use the following block of code, and have a read through. Try and summarise what each line is doing and write it below. No worries if not all of it makes sense for now.
#
# With the data merged, we can count the occurrences of each product name to see what the most purchased items are.

# %%
order_baskets = pd.merge(order_products_prior,products, on=['product_id'], how='inner')
order_baskets['product_name'].value_counts().rename("freq")
# Out:
# Banana                                                               321
# Bag of Organic Bananas                                               236
# Organic Strawberries                                                 163
# Organic Baby Spinach                                                 137
# Organic Hass Avocado                                                 129
# Organic Avocado                                                      108
# Strawberries                                                          95
# Large Lemon                                                           91
# Organic Raspberries                                                   87
# Limes                                                                 77
# Organic Yellow Onion                                                  72
# Organic Whole Milk                                                    70
# Organic Garlic                                                        69
# Organic Fuji Apple                                                    65
# Honeycrisp Apple                                                      62
# Organic Blueberries                                                   59
# Organic Lemon                                                         55
# Cucumber Kirby                                                        54
# Organic Half & Half                                                   53
# Original Hummus                                                       53
# Apple Honeycrisp Organic                                              53
# Organic Zucchini                                                      52
# Organic Grape Tomatoes                                                51
# Organic Large Extra Fancy Fuji Apple                                  48
# Carrots                                                               47
# Organic Blackberries                                                  47
# Organic Cilantro                                                      45
# Raspberries                                                           45
# Organic Baby Carrots                                                  45
# Organic Cucumber                                                      44
#                                                                     ...
# Single Serve Crispy Wheat Crackers                                     1
# Nux Vomica 6C Homeopathic Pellets                                      1
# Coffee Liqueur                                                         1
# Mixed Berry Goat Milk Yogurt and Fruit                                 1
# Gluten-Free Smart Puffs Real Wisconsin Cheddar Baked Cheese Puffs      1
# Ciabatta Rolls                                                         1
# Classic Meatless Meatballs                                             1
# Sea Salt & Pepper Popcorn                                              1
# Organic Rolled Oats                                                    1
# Feta Cheese                                                            1
# Ultra Free & Clear Dishwashing Liquid                                  1
# Heritage O's Multigrain Cereal                                         1
# Natural Sour Cream                                                     1
# Organic Wheat-Free & Gluten-Free Original Crackers                     1
# Organic Ice Cream Cones                                                1
# Organic Light in Sodium Low-Fat Minestrone Soup                        1
# Italian Squash                                                         1
# from Concentrate Mango Nectar                                          1
# Snack Stacks! Original Potato Crisps                                   1
# Angel Flake Sweetened Coconut                                          1
# Baked Cheddar Bunnies Crackers                                         1
# Naked Sponges - 2 CT                                                   1
# Franks                                                                 1
# Organic Pine Nuts                                                      1
# Villalobos, Caturra, Catuai Coffee                                     1
# Lightly Salted Kettle Potato Chips - Sea Salt                          1
# Organic Mushroom Base                                                  1
# Sun Dried Tomato Basil Chicken Sausage                                 1
# Essential Orange-Orange Vitamin Water Drink                            1
# Ultimate Flora Probiotic Sour Gummies                                  1
# Name: freq, Length: 6984, dtype: int64

# %% [markdown]
# ## Grouping orders
#
# At the moment each item in a transaction is separate in the dataframe. We will need to group each product in an array for each transaction. This will also reduce the number of entries into the dateframe.
# Once we have done that, take a look at the first few entries to see how it's changed.

# %%
order_baskets = order_baskets.groupby(['order_id']).product_name.apply(np.array).reset_index()
order_baskets.head()
# Out:
#    order_id                                       product_name
# 0         2  [Organic Egg Whites, Michigan Organic Kale, Ga...
# 1         3  [Total 2% with Strawberry Lowfat Greek Straine...
# 2         4  [Plain Pre-Sliced Bagels, Honey/Lemon Cough Dr...
# 3         5  [Bag of Organic Bananas, Just Crisp, Parmesan,...
# 4         6  [Cleanse, Dryer Sheets Geranium Scent, Clean D...

# %% [markdown]
# ## Explore & Transform
#
# To work efficiently, Association Rules require something called a sparse matrix. A sparse matrix is basically a big table where any cell without a value in it is ignored by a computer.
#
# Creating a sparse matrix cuts out a lot of time and computational effort because a computer doesn't have to look at a great many cells within a dataframe - as far as the computer is concerned, empty cells don't exist.

# %%
#transactions = order_baskets.iloc[:,1:].values
te = TransactionEncoder()
te_ary = te.fit(order_baskets['product_name']).transform(order_baskets['product_name'])
dataset = pd.DataFrame(te_ary, columns=te.columns_)
dataset
# Out:
#       & Go! Hazelnut Spread + Pretzel Sticks  0% Fat Blueberry Greek Yogurt  \
# 0                                      False                          False
# 1                                      False                          False
# 2                                      False                          False
# 3                                      False                          False
# 4                                      False                          False
# 5                                      False                          False
# 6                                      False                          False
# 7                                      False                          False
# 8                                      False                          False
# 9                                      False                          False
# 10                                     False                          False
# 11                                     False                          False
# 12                                     False                          False
# 13                                     False                          False
# 14                                     False                          False
# 15                                     False                          False
# 16                                     False                          False
# 17                                     False                          False
# 18                                     False                          False
# 19                                     False                          False
# 20                                     False                          False
# 21                                     False                          False
# 22                                     False                          False
# 23                                     False                          False
# 24                                     False                          False
# 25                                     False                          False
# 26                                     False                          False
# 27                                     False                          False
# 28                                     False                          False
# 29                                     False                          False
# ...                                      ...                            ...
# 2001                                   False                          False
# 2002                                   False                          False
# 2003                                   False                          False
# 2004                                   False                          False
# 2005                                   False                          False
# 2006                                   False                          False
# 2007                                   False                          False
# 2008                                   False                          False
# 2009                                   False                          False
# 2010                                   False                          False
# 2011                                   False                          False
# 2012                                   False                          False
# 2013                                   False                          False
# 2014                                   False                          False
# 2015                                   False                          False
# 2016                                   False                          False
# 2017                                   False                          False
# 2018                                   False                          False
# 2019                                   False                          False
# 2020                                   False                          False
# 2021                                   False                          False
# 2022                                   False                          False
# 2023                                   False                          False
# 2024                                   False                          False
# 2025                                   False                          False
# 2026                                   False                          False
# 2027                                   False                          False
# 2028                                   False                          False
# 2029                                   False                          False
# 2030                                   False                          False
#
#       0% Fat Free Organic Milk  0% Fat Organic Greek Vanilla Yogurt  \
# 0                        False                                False
# 1                        False                                False
# 2                        False                                False
# 3                        False                                False
# 4                        False                                False
# 5                        False                                False
# 6                        False                                False
# 7                        False                                False
# 8                        False                                False
# 9                        False                                False
# 10                       False                                False
# 11                       False                                False
# 12                       False                                False
# 13                       False                                False
# 14                       False                                False
# 15                       False                                False
# 16                       False                                False
# 17                       False                                False
# 18                       False                                False
# 19                       False                                False
# 20                       False                                False
# 21                       False                                False
# 22                       False                                False
# 23                       False                                False
# 24                       False                                False
# 25                       False                                False
# 26                       False                                False
# 27                       False                                False
# 28                       False                                False
# 29                       False                                False
# ...                        ...                                  ...
# 2001                     False                                False
# 2002                     False                                False
# 2003                     False                                False
# 2004                     False                                False
# 2005                     False                                False
# 2006                     False                                False
# 2007                     False                                False
# 2008                     False                                False
# 2009                     False                                False
# 2010                     False                                False
# 2011                     False                                False
# 2012                     False                                False
# 2013                     False                                False
# 2014                     False                                False
# 2015                     False                                False
# 2016                     False                                False
# 2017                     False                                False
# 2018                     False                                False
# 2019                     False                                False
# 2020                     False                                False
# 2021                     False                                False
# 2022                     False                                False
# 2023                     False                                False
# 2024                     False                                False
# 2025                     False                                False
# 2026                     False                                False
# 2027                     False                                False
# 2028                     False                                False
# 2029                     False                                False
# 2030                     False                                False
#
#       0% Greek Strained Yogurt  0% Greek Yogurt Black Cherry on the Bottom  \
# 0                        False                                       False
# 1                        False                                       False
# 2                        False                                       False
# 3                        False                                       False
# 4                        False                                       False
# 5                        False                                       False
# 6                        False                                       False
# 7                        False                                       False
# 8                        False                                       False
# 9                        False                                       False
# 10                       False                                       False
# 11                       False                                       False
# 12                       False                                       False
# 13                       False                                       False
# 14                       False                                       False
# 15                       False                                       False
# 16                       False                                       False
# 17                       False                                       False
# 18                       False                                       False
# 19                       False                                       False
# 20                       False                                       False
# 21                       False                                       False
# 22                       False                                       False
# 23                       False                                       False
# 24                       False                                       False
# 25                       False                                       False
# 26                       False                                       False
# 27                       False                                       False
# 28                       False                                       False
# 29                       False                                       False
# ...                        ...                                         ...
# 2001                     False                                       False
# 2002                     False                                       False
# 2003                     False                                       False
# 2004                     False                                       False
# 2005                     False                                       False
# 2006                     False                                       False
# 2007                     False                                       False
# 2008                     False                                       False
# 2009                     False                                       False
# 2010                     False                                       False
# 2011                     False                                       False
# 2012                     False                                       False
# 2013                     False                                       False
# 2014                     False                                       False
# 2015                     False                                       False
# 2016                     False                                       False
# 2017                     False                                       False
# 2018                     False                                       False
# 2019                     False                                       False
# 2020                     False                                       False
# 2021                     False                                       False
# 2022                     False                                       False
# 2023                     False                                       False
# 2024                     False                                       False
# 2025                     False                                       False
# 2026                     False                                       False
# 2027                     False                                       False
# 2028                     False                                       False
# 2029                     False                                       False
# 2030                     False                                       False
#
#       0% Milkfat Greek Plain Yogurt  0% Milkfat Greek Yogurt Honey  \
# 0                             False                          False
# 1                             False                          False
# 2                             False                          False
# 3                             False                          False
# 4                             False                          False
# 5                             False                          False
# 6                             False                          False
# 7                             False                          False
# 8                             False                          False
# 9                             False                          False
# 10                            False                          False
# 11                            False                          False
# 12                            False                          False
# 13                            False                          False
# 14                            False                          False
# 15                            False                          False
# 16                            False                          False
# 17                            False                          False
# 18                            False                          False
# 19                            False                          False
# 20                            False                          False
# 21                            False                          False
# 22                            False                          False
# 23                            False                          False
# 24                            False                          False
# 25                            False                          False
# 26                            False                          False
# 27                            False                          False
# 28                            False                          False
# 29                            False                          False
# ...                             ...                            ...
# 2001                          False                          False
# 2002                          False                          False
# 2003                          False                          False
# 2004                          False                          False
# 2005                          False                          False
# 2006                          False                          False
# 2007                          False                          False
# 2008                          False                          False
# 2009                          False                          False
# 2010                          False                          False
# 2011                          False                          False
# 2012                          False                          False
# 2013                          False                          False
# 2014                          False                          False
# 2015                          False                          False
# 2016                          False                          False
# 2017                          False                          False
# 2018                          False                          False
# 2019                          False                          False
# 2020                          False                          False
# 2021                          False                          False
# 2022                          False                          False
# 2023                          False                          False
# 2024                          False                          False
# 2025                          False                          False
# 2026                          False                          False
# 2027                          False                          False
# 2028                          False                          False
# 2029                          False                          False
# 2030                          False                          False
#
#       1 % Lowfat Milk  1 Apple + 1 Mango Fruit Bar  \
# 0               False                        False
# 1               False                        False
# 2               False                        False
# 3               False                        False
# 4               False                        False
# 5               False                        False
# 6               False                        False
# 7               False                        False
# 8               False                        False
# 9               False                        False
# 10              False                        False
# 11              False                        False
# 12              False                        False
# 13              False                        False
# 14              False                        False
# 15              False                        False
# 16              False                        False
# 17              False                        False
# 18              False                        False
# 19              False                        False
# 20              False                        False
# 21              False                        False
# 22              False                        False
# 23              False                        False
# 24              False                        False
# 25              False                        False
# 26              False                        False
# 27              False                        False
# 28              False                        False
# 29              False                        False
# ...               ...                          ...
# 2001            False                        False
# 2002            False                        False
# 2003            False                        False
# 2004            False                        False
# 2005            False                        False
# 2006            False                        False
# 2007            False                        False
# 2008            False                        False
# 2009            False                        False
# 2010            False                        False
# 2011            False                        False
# 2012            False                        False
# 2013            False                        False
# 2014            False                        False
# 2015            False                        False
# 2016            False                        False
# 2017            False                        False
# 2018            False                        False
# 2019            False                        False
# 2020            False                        False
# 2021            False                        False
# 2022            False                        False
# 2023            False                        False
# 2024            False                        False
# 2025            False                        False
# 2026            False                        False
# 2027            False                        False
# 2028            False                        False
# 2029            False                        False
# 2030            False                        False
#
#                      ...                  Zucchini Noodles  \
# 0                    ...                             False
# 1                    ...                             False
# 2                    ...                             False
# 3                    ...                             False
# 4                    ...                             False
# 5                    ...                             False
# 6                    ...                             False
# 7                    ...                             False
# 8                    ...                             False
# 9                    ...                             False
# 10                   ...                             False
# 11                   ...                             False
# 12                   ...                             False
# 13                   ...                             False
# 14                   ...                             False
# 15                   ...                             False
# 16                   ...                             False
# 17                   ...                             False
# 18                   ...                             False
# 19                   ...                             False
# 20                   ...                             False
# 21                   ...                             False
# 22                   ...                             False
# 23                   ...                             False
# 24                   ...                             False
# 25                   ...                             False
# 26                   ...                             False
# 27                   ...                             False
# 28                   ...                             False
# 29                   ...                             False
# ...                  ...                               ...
# 2001                 ...                             False
# 2002                 ...                             False
# 2003                 ...                             False
# 2004                 ...                             False
# 2005                 ...                             False
# 2006                 ...                             False
# 2007                 ...                             False
# 2008                 ...                             False
# 2009                 ...                             False
# 2010                 ...                             False
# 2011                 ...                             False
# 2012                 ...                             False
# 2013                 ...                             False
# 2014                 ...                             False
# 2015                 ...                             False
# 2016                 ...                             False
# 2017                 ...                             False
# 2018                 ...                             False
# 2019                 ...                             False
# 2020                 ...                             False
# 2021                 ...                             False
# 2022                 ...                             False
# 2023                 ...                             False
# 2024                 ...                             False
# 2025                 ...                             False
# 2026                 ...                             False
# 2027                 ...                             False
# 2028                 ...                             False
# 2029                 ...                             False
# 2030                 ...                             False
#
#       from Concentrate Mango Nectar  gel hand wash sea minerals  \
# 0                             False                       False
# 1                             False                       False
# 2                             False                       False
# 3                             False                       False
# 4                             False                       False
# 5                             False                       False
# 6                             False                       False
# 7                             False                       False
# 8                             False                       False
# 9                             False                       False
# 10                            False                       False
# 11                            False                       False
# 12                            False                       False
# 13                            False                       False
# 14                            False                       False
# 15                            False                       False
# 16                            False                       False
# 17                            False                       False
# 18                            False                       False
# 19                            False                       False
# 20                            False                       False
# 21                            False                       False
# 22                            False                       False
# 23                            False                       False
# 24                            False                       False
# 25                            False                       False
# 26                            False                       False
# 27                            False                       False
# 28                            False                       False
# 29                            False                       False
# ...                             ...                         ...
# 2001                          False                       False
# 2002                          False                       False
# 2003                          False                       False
# 2004                          False                       False
# 2005                          False                       False
# 2006                          False                       False
# 2007                          False                       False
# 2008                          False                       False
# 2009                          False                       False
# 2010                          False                       False
# 2011                          False                       False
# 2012                          False                       False
# 2013                          False                       False
# 2014                          False                       False
# 2015                          False                       False
# 2016                          False                       False
# 2017                          False                       False
# 2018                          False                       False
# 2019                          False                       False
# 2020                          False                       False
# 2021                          False                       False
# 2022                          False                       False
# 2023                          False                       False
# 2024                          False                       False
# 2025                          False                       False
# 2026                          False                       False
# 2027                          False                       False
# 2028                          False                       False
# 2029                          False                       False
# 2030                          False                       False
#
#       in Gravy with Carrots Peas & Corn Mashed Potatoes & Meatloaf Nuggets  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# 5                                                 False
# 6                                                 False
# 7                                                 False
# 8                                                 False
# 9                                                 False
# 10                                                False
# 11                                                False
# 12                                                False
# 13                                                False
# 14                                                False
# 15                                                False
# 16                                                False
# 17                                                False
# 18                                                False
# 19                                                False
# 20                                                False
# 21                                                False
# 22                                                False
# 23                                                False
# 24                                                False
# 25                                                False
# 26                                                False
# 27                                                False
# 28                                                False
# 29                                                False
# ...                                                 ...
# 2001                                              False
# 2002                                              False
# 2003                                              False
# 2004                                              False
# 2005                                              False
# 2006                                              False
# 2007                                              False
# 2008                                              False
# 2009                                              False
# 2010                                              False
# 2011                                              False
# 2012                                              False
# 2013                                              False
# 2014                                              False
# 2015                                              False
# 2016                                              False
# 2017                                              False
# 2018                                              False
# 2019                                              False
# 2020                                              False
# 2021                                              False
# 2022                                              False
# 2023                                              False
# 2024                                              False
# 2025                                              False
# 2026                                              False
# 2027                                              False
# 2028                                              False
# 2029                                              False
# 2030                                              False
#
#       of Norwich Original English Mustard Powder Double Superfine  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# 5                                                 False
# 6                                                 False
# 7                                                 False
# 8                                                 False
# 9                                                 False
# 10                                                False
# 11                                                False
# 12                                                False
# 13                                                False
# 14                                                False
# 15                                                False
# 16                                                False
# 17                                                False
# 18                                                False
# 19                                                False
# 20                                                False
# 21                                                False
# 22                                                False
# 23                                                False
# 24                                                False
# 25                                                False
# 26                                                False
# 27                                                False
# 28                                                False
# 29                                                False
# ...                                                 ...
# 2001                                              False
# 2002                                              False
# 2003                                              False
# 2004                                              False
# 2005                                              False
# 2006                                              False
# 2007                                              False
# 2008                                              False
# 2009                                              False
# 2010                                              False
# 2011                                              False
# 2012                                              False
# 2013                                              False
# 2014                                              False
# 2015                                              False
# 2016                                              False
# 2017                                              False
# 2018                                              False
# 2019                                              False
# 2020                                              False
# 2021                                              False
# 2022                                              False
# 2023                                              False
# 2024                                              False
# 2025                                              False
# 2026                                              False
# 2027                                              False
# 2028                                              False
# 2029                                              False
# 2030                                              False
#
#       smartwater® Electrolyte Enhanced Water  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# 5                                      False
# 6                                      False
# 7                                      False
# 8                                      False
# 9                                      False
# 10                                     False
# 11                                     False
# 12                                     False
# 13                                     False
# 14                                     False
# 15                                     False
# 16                                     False
# 17                                     False
# 18                                     False
# 19                                     False
# 20                                     False
# 21                                     False
# 22                                     False
# 23                                     False
# 24                                     False
# 25                                     False
# 26                                     False
# 27                                     False
# 28                                     False
# 29                                     False
# ...                                      ...
# 2001                                   False
# 2002                                   False
# 2003                                   False
# 2004                                   False
# 2005                                   False
# 2006                                   False
# 2007                                   False
# 2008                                   False
# 2009                                   False
# 2010                                   False
# 2011                                   False
# 2012                                   False
# 2013                                   False
# 2014                                   False
# 2015                                   False
# 2016                                   False
# 2017                                   False
# 2018                                   False
# 2019                                   False
# 2020                                   False
# 2021                                   False
# 2022                                   False
# 2023                                   False
# 2024                                   False
# 2025                                   False
# 2026                                   False
# 2027                                   False
# 2028                                   False
# 2029                                   False
# 2030                                   False
#
#       vitaminwater® XXX Acai Blueberry Pomegranate  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# 5                                            False
# 6                                            False
# 7                                            False
# 8                                            False
# 9                                            False
# 10                                           False
# 11                                           False
# 12                                           False
# 13                                           False
# 14                                           False
# 15                                           False
# 16                                           False
# 17                                           False
# 18                                           False
# 19                                           False
# 20                                           False
# 21                                           False
# 22                                           False
# 23                                           False
# 24                                           False
# 25                                           False
# 26                                           False
# 27                                           False
# 28                                           False
# 29                                           False
# ...                                            ...
# 2001                                         False
# 2002                                         False
# 2003                                         False
# 2004                                         False
# 2005                                         False
# 2006                                         False
# 2007                                         False
# 2008                                         False
# 2009                                         False
# 2010                                         False
# 2011                                         False
# 2012                                         False
# 2013                                         False
# 2014                                         False
# 2015                                         False
# 2016                                         False
# 2017                                         False
# 2018                                         False
# 2019                                         False
# 2020                                         False
# 2021                                         False
# 2022                                         False
# 2023                                         False
# 2024                                         False
# 2025                                         False
# 2026                                         False
# 2027                                         False
# 2028                                         False
# 2029                                         False
# 2030                                         False
#
#       with Crispy Almonds Cereal  with Olive Oil Mayonnaise  \
# 0                          False                      False
# 1                          False                      False
# 2                          False                      False
# 3                          False                      False
# 4                          False                      False
# 5                          False                      False
# 6                          False                      False
# 7                          False                      False
# 8                          False                      False
# 9                          False                      False
# 10                         False                      False
# 11                         False                      False
# 12                         False                      False
# 13                         False                      False
# 14                         False                      False
# 15                         False                      False
# 16                         False                      False
# 17                         False                      False
# 18                         False                      False
# 19                         False                      False
# 20                         False                      False
# 21                         False                      False
# 22                         False                      False
# 23                         False                      False
# 24                         False                      False
# 25                         False                      False
# 26                         False                      False
# 27                         False                      False
# 28                         False                      False
# 29                         False                      False
# ...                          ...                        ...
# 2001                       False                      False
# 2002                       False                      False
# 2003                       False                      False
# 2004                       False                      False
# 2005                       False                      False
# 2006                       False                      False
# 2007                       False                      False
# 2008                       False                      False
# 2009                       False                      False
# 2010                       False                      False
# 2011                       False                      False
# 2012                       False                      False
# 2013                       False                      False
# 2014                       False                      False
# 2015                       False                      False
# 2016                       False                      False
# 2017                       False                      False
# 2018                       False                      False
# 2019                       False                      False
# 2020                       False                      False
# 2021                       False                      False
# 2022                       False                      False
# 2023                       False                      False
# 2024                       False                      False
# 2025                       False                      False
# 2026                       False                      False
# 2027                       False                      False
# 2028                       False                      False
# 2029                       False                      False
# 2030                       False                      False
#
#       with Olive Oil Mayonnaise Dressing
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# 5                                  False
# 6                                  False
# 7                                  False
# 8                                  False
# 9                                  False
# 10                                 False
# 11                                 False
# 12                                 False
# 13                                 False
# 14                                 False
# 15                                 False
# 16                                 False
# 17                                 False
# 18                                 False
# 19                                 False
# 20                                 False
# 21                                 False
# 22                                 False
# 23                                 False
# 24                                 False
# 25                                 False
# 26                                 False
# 27                                 False
# 28                                 False
# 29                                 False
# ...                                  ...
# 2001                               False
# 2002                               False
# 2003                               False
# 2004                               False
# 2005                               False
# 2006                               False
# 2007                               False
# 2008                               False
# 2009                               False
# 2010                               False
# 2011                               False
# 2012                               False
# 2013                               False
# 2014                               False
# 2015                               False
# 2016                               False
# 2017                               False
# 2018                               False
# 2019                               False
# 2020                               False
# 2021                               False
# 2022                               False
# 2023                               False
# 2024                               False
# 2025                               False
# 2026                               False
# 2027                               False
# 2028                               False
# 2029                               False
# 2030                               False
#
# [2031 rows x 6984 columns]

# %% [markdown]
# ## Create Rules: Most common set of items bought
#
# We can create a rule that will determine the most frequent itemsets; that is, which collections of items are bought most often.
# The `support` of a given itemset is the percentage of total transactions in which that itemset was bought. A support of 0.01 for a given itemset means that that itemset was bought in 1% of all transactions. We also need to establish the minimum itemset length to 2 using lambda functions.

# %%
frequent_itemsets = apriori(dataset, min_support=0.01, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets = frequent_itemsets[ (frequent_itemsets['length'] == 2)]
frequent_itemsets
# Out:
#       support                                        itemsets  length
# 108  0.010340  [Bag of Organic Bananas, Organic Baby Spinach]       2
# 109  0.018710  [Bag of Organic Bananas, Organic Hass Avocado]       2
# 110  0.013786   [Bag of Organic Bananas, Organic Raspberries]       2
# 111  0.016248  [Bag of Organic Bananas, Organic Strawberries]       2
# 112  0.010832                        [Banana, Cucumber Kirby]       2
# 113  0.011817                      [Banana, Honeycrisp Apple]       2
# 114  0.010340                           [Banana, Large Lemon]       2
# 115  0.016741                       [Banana, Organic Avocado]       2
# 116  0.016741                  [Banana, Organic Baby Spinach]       2
# 117  0.014279                    [Banana, Organic Fuji Apple]       2
# 118  0.016741                  [Banana, Organic Strawberries]       2
# 119  0.012802                          [Banana, Strawberries]       2
# 120  0.010832    [Organic Hass Avocado, Organic Strawberries]       2

# %% [markdown]
# ## Create Rules: First set of Association Rules
#
# Now we are going to create a set of rules to get items often bought with itemsets.
# We know from the last couple of steps that the support is the frequency with which itemset appears in the dataset.
#
# Confidence is how often a rule is found to be true. More precisely, for a given rule from an antecedent itemset X to a set Y, the confidence of that rule is equal to the Support of the intersection of X with Y, divided by the Support of X alone. e.g. If {eggs, milk} => {bread} has a confidence of 0.6 and the itemset {eggs, milk} has a support of 0.0001, then eggs and milk appear in 0.01% of all transactions, and 60% of the time that eggs and milk are bought, bread is bought as well.
#
# > Create a set of association rules using the `apriori` algorithm.
# > Then print out a summary of your rules and inspect the first rule
#
# *Hint: To get you started some sensible default options*
# - Use the confidence and support values mentioned above. Low support (appears infrequently) but high confidence (bought often together).
# - Set `antecedent_len=3` to only evaluate itemsets of 2 or 3 items

# %%
frequent_itemsets = apriori(dataset, min_support=0.003, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.3)
rules["antecedent_len"] = rules["antecedents"].apply(lambda x: len(x))
rules[ (rules['antecedent_len'] >= 2)]
# Out:
#                                           antecedents  \
# 62        (Organic Hass Avocado, Organic Raspberries)
# 63       (Organic Hass Avocado, Organic Strawberries)
# 64  (Boneless Skinless Chicken Breasts, Organic Ba...
# 65        (Boneless Skinless Chicken Breasts, Banana)
# 66            (Organic Strawberries, Organic Avocado)
# 67           (Organic Zucchini, Organic Baby Spinach)
# 68                         (Organic Zucchini, Banana)
# 69       (Organic Blackberries, Organic Strawberries)
# 70                     (Organic Blackberries, Banana)
#
#                  consequents  antecedent support  consequent support  \
# 62  (Bag of Organic Bananas)            0.008370            0.116199
# 63  (Bag of Organic Bananas)            0.010832            0.116199
# 64                  (Banana)            0.004431            0.158050
# 65    (Organic Baby Spinach)            0.008370            0.067454
# 66                  (Banana)            0.008370            0.158050
# 67                  (Banana)            0.007386            0.158050
# 68    (Organic Baby Spinach)            0.007386            0.067454
# 69                  (Banana)            0.006893            0.158050
# 70    (Organic Strawberries)            0.006893            0.080256
#
#      support  confidence      lift  leverage  conviction  antecedent_len
# 62  0.003939    0.470588  4.049850  0.002966    1.669402               2
# 63  0.003939    0.363636  3.129430  0.002680    1.388830               2
# 64  0.003447    0.777778  4.921080  0.002746    3.788774               2
# 65  0.003447    0.411765  6.104337  0.002882    1.585327               2
# 66  0.003447    0.411765  2.605278  0.002124    1.431315               2
# 67  0.003447    0.466667  2.952648  0.002279    1.578656               2
# 68  0.003447    0.466667  6.918248  0.002948    1.748523               2
# 69  0.003447    0.500000  3.163551  0.002357    1.683900               2
# 70  0.003447    0.500000  6.230061  0.002893    1.839488               2

# %% [markdown]
# Note: when you inspect a rule you'll get something like this:
# ```
# antecedents	- (Organic Hass Avocado, Organic Raspberries)
# consequents - (Bag of Organic Bananas)
# antecedent support - 0.008370
# consequent support - 0.116199
# support	confidence - 0.003939
# lift - 0.470588
# leverage - 0.002966
# conviction - 1.669402
# antecedant_len - 2
# ```
#
# Note: It might look more complicated, but the important things are
# - *antecedents* stands for "when people buy these products"
# - *consequents* stands for "they are likely to buy this, too"
# - *support	confidence* is how often a rule is found to be true
# - *Lift* explained below
# - *antecedent_len* stands for the number of items with the antecedent item set
#
# You might also notice how the confidence is 1 for some of the rules. That means the rule is correct 100% of the time but how can that be?
# If the support is really low, such as 0.0001, then the rule only needs to appear in 0.08% of the transactions to be accepted. In a dataset with 20,000 transations, only 2 out of 2 people need to adhere to the rule for it to have a confidence of 1. This is why a support too low can give you useless data.
#
# Note: If it is taking too long to run, increase the support. Python isn't as efficient as R as you cant set the min and max length until after so item sets of all lengths are evaluated making it slow!

# %%
frequent_itemsets = apriori(dataset, min_support=0.001, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
rules["antecedent_len"] = rules["antecedents"].apply(lambda x: len(x))
rules[ (rules['antecedent_len'] >= 2)]
# Out:
#                                            antecedents  \
# 85                    (100% Raw Coconut Water, Banana)
# 86       (Organic Raspberries, 100% Whole Wheat Bread)
# 87   (Apple Cinnamon GoGo Squeez, Organic Strawberr...
# 88                (Apple Cinnamon GoGo Squeez, Banana)
# 89        (Apple Honeycrisp Organic, Organic Broccoli)
# 90   (Apple Honeycrisp Organic, Organic Reduced Fat...
# 91        (Apple Honeycrisp Organic, Organic Broccoli)
# 92            (Organic Broccoli, Organic Baby Spinach)
# 93                   (Asparagus, Organic Strawberries)
# 94                   (Asparagus, Organic Yellow Onion)
# 95   (Organic Strawberries, Asparation/Broccolini/B...
# 96    (Organic Hass Avocado, Authentic French Brioche)
# 97    (Authentic French Brioche, Organic Strawberries)
# 98   (Bag of Organic Bananas, Boneless Skinless Chi...
# 99   (Organic Small Bunch Celery, Boneless Skinless...
# 100                         (Carrots, Organic Avocado)
# 101                    (Organic Hass Avocado, Carrots)
# 102                     (Organic Raspberries, Carrots)
# 103                (Carrots, Organic Spring Mix Salad)
# 104  (Organic Lacinato (Dinosaur) Kale, Frozen Orga...
# 105             (Organic Hass Avocado, Marinara Sauce)
# 106  (Organic Small Bunch Celery, Michigan Organic ...
# 107         (Organic Hass Avocado, Organic AppleApple)
# 108            (Organic Baby Arugula, Original Hummus)
# 109       (Sharp Cheddar Cheese, Organic Baby Arugula)
# 110           (Organic Blackberries, Organic Cilantro)
# 111      (Organic D'Anjou Pears, Organic Blackberries)
# 112       (Organic Hass Avocado, Organic Blackberries)
# 113            (Organic Raspberries, Organic Cucumber)
# 114         (Organic Cucumber, Unsweetened Almondmilk)
# ..                                                 ...
# 382      (Organic Lemon, Organic Strawberries, Banana)
# 383  (Peach on the Bottom Nonfat Greek Yogurt, Blue...
# 384  (Peach on the Bottom Nonfat Greek Yogurt, Stra...
# 385  (Peach on the Bottom Nonfat Greek Yogurt, Blue...
# 386  (Non Fat Black Cherry on the Bottom Greek Yogu...
# 387  (Peach on the Bottom Nonfat Greek Yogurt, Stra...
# 388  (Non Fat Black Cherry on the Bottom Greek Yogu...
# 389  (Non Fat Black Cherry on the Bottom Greek Yogu...
# 390  (Blueberry on the Bottom Nonfat Greek Yogurt, ...
# 391  (Pomegranate on the Bottom Non-Fat Greek Yogur...
# 392  (Pomegranate on the Bottom Non-Fat Greek Yogur...
# 393  (Pomegranate on the Bottom Non-Fat Greek Yogur...
# 394  (Peach on the Bottom Nonfat Greek Yogurt, Blue...
# 395  (Pomegranate on the Bottom Non-Fat Greek Yogur...
# 396  (Pomegranate on the Bottom Non-Fat Greek Yogur...
# 397  (Pomegranate on the Bottom Non-Fat Greek Yogur...
# 398  (Peach on the Bottom Nonfat Greek Yogurt, Stra...
# 399  (Blueberry on the Bottom Nonfat Greek Yogurt, ...
# 401  (Peach on the Bottom Nonfat Greek Yogurt, Rasp...
# 402  (Peach on the Bottom Nonfat Greek Yogurt, Rasp...
# 403  (Peach on the Bottom Nonfat Greek Yogurt, Blue...
# 404  (Raspberry on the Bottom Nonfat Greek Yogurt, ...
# 405  (Peach on the Bottom Nonfat Greek Yogurt, Rasp...
# 406  (Peach on the Bottom Nonfat Greek Yogurt, Stra...
# 407  (Raspberry on the Bottom Nonfat Greek Yogurt, ...
# 408  (Raspberry on the Bottom Nonfat Greek Yogurt, ...
# 409  (Blueberry on the Bottom Nonfat Greek Yogurt, ...
# 410        (Limes, Organic Raspberries, Organic Lemon)
# 411  (Limes, Organic Raspberries, Organic Strawberr...
# 412       (Limes, Organic Lemon, Organic Strawberries)
#
#                                            consequents  antecedent support  \
# 85                               (Organic Raspberries)            0.002462
# 86                            (Bag of Organic Bananas)            0.001969
# 87                                            (Banana)            0.001969
# 88                              (Organic Strawberries)            0.001477
# 89                                            (Banana)            0.001477
# 90                                            (Banana)            0.001969
# 91                              (Organic Baby Spinach)            0.001477
# 92                          (Apple Honeycrisp Organic)            0.001477
# 93                            (Bag of Organic Bananas)            0.001477
# 94                              (Organic Baby Spinach)            0.001969
# 95                                       (Large Lemon)            0.001477
# 96                              (Organic Strawberries)            0.001969
# 97                              (Organic Hass Avocado)            0.001969
# 98                        (Organic Small Bunch Celery)            0.001477
# 99                            (Bag of Organic Bananas)            0.001969
# 100                           (Bag of Organic Bananas)            0.002462
# 101                           (Bag of Organic Bananas)            0.001969
# 102                           (Bag of Organic Bananas)            0.002462
# 103                           (Bag of Organic Bananas)            0.001969
# 104                           (Bag of Organic Bananas)            0.001477
# 105                           (Bag of Organic Bananas)            0.001477
# 106                           (Bag of Organic Bananas)            0.001477
# 107                           (Bag of Organic Bananas)            0.001969
# 108                           (Bag of Organic Bananas)            0.003939
# 109                           (Bag of Organic Bananas)            0.001477
# 110                           (Bag of Organic Bananas)            0.001477
# 111                           (Bag of Organic Bananas)            0.001969
# 112                           (Bag of Organic Bananas)            0.002462
# 113                           (Bag of Organic Bananas)            0.002462
# 114                           (Bag of Organic Bananas)            0.001477
# ..                                                 ...                 ...
# 382                              (Organic Raspberries)            0.001969
# 383     (Strawberry on the Bottom Nonfat Greek Yogurt)            0.001477
# 384      (Blueberry on the Bottom Nonfat Greek Yogurt)            0.001477
# 385  (Non Fat Black Cherry on the Bottom Greek Yogurt)            0.001969
# 386          (Peach on the Bottom Nonfat Greek Yogurt)            0.001477
# 387  (Non Fat Black Cherry on the Bottom Greek Yogu...            0.001969
# 388  (Peach on the Bottom Nonfat Greek Yogurt, Stra...            0.001477
# 389  (Peach on the Bottom Nonfat Greek Yogurt, Blue...            0.001477
# 390  (Peach on the Bottom Nonfat Greek Yogurt, Non ...            0.001969
# 391     (Strawberry on the Bottom Nonfat Greek Yogurt)            0.001969
# 392      (Blueberry on the Bottom Nonfat Greek Yogurt)            0.001477
# 393          (Peach on the Bottom Nonfat Greek Yogurt)            0.001477
# 394   (Pomegranate on the Bottom Non-Fat Greek Yogurt)            0.001969
# 395  (Blueberry on the Bottom Nonfat Greek Yogurt, ...            0.001969
# 396  (Peach on the Bottom Nonfat Greek Yogurt, Stra...            0.001969
# 397  (Peach on the Bottom Nonfat Greek Yogurt, Blue...            0.001477
# 398  (Pomegranate on the Bottom Non-Fat Greek Yogur...            0.001969
# 399  (Pomegranate on the Bottom Non-Fat Greek Yogur...            0.001969
# 401     (Strawberry on the Bottom Nonfat Greek Yogurt)            0.001477
# 402      (Blueberry on the Bottom Nonfat Greek Yogurt)            0.001477
# 403      (Raspberry on the Bottom Nonfat Greek Yogurt)            0.001969
# 404          (Peach on the Bottom Nonfat Greek Yogurt)            0.001477
# 405  (Blueberry on the Bottom Nonfat Greek Yogurt, ...            0.001477
# 406  (Raspberry on the Bottom Nonfat Greek Yogurt, ...            0.001969
# 407  (Peach on the Bottom Nonfat Greek Yogurt, Stra...            0.001477
# 408  (Peach on the Bottom Nonfat Greek Yogurt, Blue...            0.001477
# 409  (Peach on the Bottom Nonfat Greek Yogurt, Rasp...            0.001969
# 410                             (Organic Strawberries)            0.001477
# 411                                    (Organic Lemon)            0.001477
# 412                              (Organic Raspberries)            0.001477
#
#      consequent support   support  confidence        lift  leverage  \
# 85             0.042836  0.001969        0.80   18.675862  0.001864
# 86             0.116199  0.001969        1.00    8.605932  0.001741
# 87             0.158050  0.001477        0.75    4.745327  0.001166
# 88             0.080256  0.001477        1.00   12.460123  0.001359
# 89             0.158050  0.001477        1.00    6.327103  0.001244
# 90             0.158050  0.001477        0.75    4.745327  0.001166
# 91             0.067454  0.001477        1.00   14.824818  0.001377
# 92             0.026096  0.001477        1.00   38.320755  0.001439
# 93             0.116199  0.001477        1.00    8.605932  0.001305
# 94             0.067454  0.001477        0.75   11.118613  0.001344
# 95             0.044806  0.001477        1.00   22.318681  0.001411
# 96             0.080256  0.001477        0.75    9.345092  0.001319
# 97             0.063516  0.001477        0.75   11.808140  0.001352
# 98             0.021172  0.001477        1.00   47.232558  0.001446
# 99             0.116199  0.001477        0.75    6.454449  0.001248
# 100            0.116199  0.001969        0.80    6.884746  0.001683
# 101            0.116199  0.001969        1.00    8.605932  0.001741
# 102            0.116199  0.001969        0.80    6.884746  0.001683
# 103            0.116199  0.001477        0.75    6.454449  0.001248
# 104            0.116199  0.001477        1.00    8.605932  0.001305
# 105            0.116199  0.001477        1.00    8.605932  0.001305
# 106            0.116199  0.001477        1.00    8.605932  0.001305
# 107            0.116199  0.001477        0.75    6.454449  0.001248
# 108            0.116199  0.002954        0.75    6.454449  0.002497
# 109            0.116199  0.001477        1.00    8.605932  0.001305
# 110            0.116199  0.001477        1.00    8.605932  0.001305
# 111            0.116199  0.001477        0.75    6.454449  0.001248
# 112            0.116199  0.001969        0.80    6.884746  0.001683
# 113            0.116199  0.001969        0.80    6.884746  0.001683
# 114            0.116199  0.001477        1.00    8.605932  0.001305
# ..                  ...       ...         ...         ...       ...
# 382            0.042836  0.001477        0.75   17.508621  0.001393
# 383            0.002462  0.001477        1.00  406.200000  0.001473
# 384            0.002462  0.001477        1.00  406.200000  0.001473
# 385            0.002462  0.001477        0.75  304.650000  0.001472
# 386            0.005908  0.001477        1.00  169.250000  0.001468
# 387            0.001477  0.001477        0.75  507.750000  0.001474
# 388            0.001969  0.001477        1.00  507.750000  0.001474
# 389            0.002462  0.001477        1.00  406.200000  0.001473
# 390            0.002462  0.001477        0.75  304.650000  0.001472
# 391            0.002462  0.001477        0.75  304.650000  0.001472
# 392            0.002462  0.001477        1.00  406.200000  0.001473
# 393            0.005908  0.001477        1.00  169.250000  0.001468
# 394            0.001969  0.001477        0.75  380.812500  0.001473
# 395            0.001969  0.001477        0.75  380.812500  0.001473
# 396            0.001969  0.001477        0.75  380.812500  0.001473
# 397            0.002462  0.001477        1.00  406.200000  0.001473
# 398            0.001969  0.001477        0.75  380.812500  0.001473
# 399            0.001969  0.001477        0.75  380.812500  0.001473
# 401            0.002462  0.001477        1.00  406.200000  0.001473
# 402            0.002462  0.001477        1.00  406.200000  0.001473
# 403            0.002462  0.001477        0.75  304.650000  0.001472
# 404            0.005908  0.001477        1.00  169.250000  0.001468
# 405            0.001969  0.001477        1.00  507.750000  0.001474
# 406            0.001477  0.001477        0.75  507.750000  0.001474
# 407            0.001969  0.001477        1.00  507.750000  0.001474
# 408            0.002462  0.001477        1.00  406.200000  0.001473
# 409            0.001477  0.001477        0.75  507.750000  0.001474
# 410            0.080256  0.001477        1.00   12.460123  0.001359
# 411            0.027080  0.001477        1.00   36.927273  0.001437
# 412            0.042836  0.001477        1.00   23.344828  0.001414
#
#      conviction  antecedant_len
# 85     4.785820               2
# 86          inf               2
# 87     3.367799               2
# 88          inf               2
# 89          inf               2
# 90     3.367799               2
# 91          inf               2
# 92          inf               2
# 93          inf               2
# 94     3.730182               2
# 95          inf               2
# 96     3.678976               2
# 97     3.745938               2
# 98          inf               2
# 99     3.535204               2
# 100    4.419005               2
# 101         inf               2
# 102    4.419005               2
# 103    3.535204               2
# 104         inf               2
# 105         inf               2
# 106         inf               2
# 107    3.535204               2
# 108    3.535204               2
# 109         inf               2
# 110         inf               2
# 111    3.535204               2
# 112    4.419005               2
# 113    4.419005               2
# 114         inf               2
# ..          ...             ...
# 382    3.828656               3
# 383         inf               3
# 384         inf               3
# 385    3.990153               3
# 386         inf               3
# 387    3.994092               2
# 388         inf               2
# 389         inf               2
# 390    3.990153               2
# 391    3.990153               3
# 392         inf               3
# 393         inf               3
# 394    3.992122               3
# 395    3.992122               2
# 396    3.992122               2
# 397         inf               2
# 398    3.992122               2
# 399    3.992122               2
# 401         inf               3
# 402         inf               3
# 403    3.990153               3
# 404         inf               3
# 405         inf               2
# 406    3.994092               2
# 407         inf               2
# 408         inf               2
# 409    3.994092               2
# 410         inf               3
# 411         inf               3
# 412         inf               3
#
# [318 rows x 10 columns]

# %% [markdown]
# ## Lift
#
# The lift of a rule is ratio of the observed support of all items in the rule to that expected if the antecedent and the consequent were independent. So lift is simply the ratio of these values: target response divided by average response.
#
# If the rule had a lift of 1, it would imply that the probability of occurrence, and that of the consequent are independent of each other.
#
# If the lift is > 1, that lets us know the degree to which those two occurrences are dependent on one another, and makes those rules potentially useful for predicting the consequent in future data sets.
#
# If the lift is < 1, that lets us know the items are mutually substitutable. This means that presence of one item has negative effect on presence of other item and vice versa.
#
# This time, let's filter by lift to take a look at some of the rules with a higher lift.

# %%
frequent_itemsets = apriori(dataset, min_support=0.003, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.4)
rules["antecedent_len"] = rules["antecedents"].apply(lambda x: len(x))
rules[ (rules['antecedent_len'] >= 2) &
       (rules['lift'] > 2) ]
# Out:
#                                           antecedents  \
# 20        (Organic Hass Avocado, Organic Raspberries)
# 21  (Boneless Skinless Chicken Breasts, Organic Ba...
# 22        (Boneless Skinless Chicken Breasts, Banana)
# 23            (Organic Strawberries, Organic Avocado)
# 24           (Organic Zucchini, Organic Baby Spinach)
# 25                         (Organic Zucchini, Banana)
# 26       (Organic Blackberries, Organic Strawberries)
# 27                     (Organic Blackberries, Banana)
#
#                  consequents  antecedent support  consequent support  \
# 20  (Bag of Organic Bananas)            0.008370            0.116199
# 21                  (Banana)            0.004431            0.158050
# 22    (Organic Baby Spinach)            0.008370            0.067454
# 23                  (Banana)            0.008370            0.158050
# 24                  (Banana)            0.007386            0.158050
# 25    (Organic Baby Spinach)            0.007386            0.067454
# 26                  (Banana)            0.006893            0.158050
# 27    (Organic Strawberries)            0.006893            0.080256
#
#      support  confidence      lift  leverage  conviction  antecedent_len
# 20  0.003939    0.470588  4.049850  0.002966    1.669402               2
# 21  0.003447    0.777778  4.921080  0.002746    3.788774               2
# 22  0.003447    0.411765  6.104337  0.002882    1.585327               2
# 23  0.003447    0.411765  2.605278  0.002124    1.431315               2
# 24  0.003447    0.466667  2.952648  0.002279    1.578656               2
# 25  0.003447    0.466667  6.918248  0.002948    1.748523               2
# 26  0.003447    0.500000  3.163551  0.002357    1.683900               2
# 27  0.003447    0.500000  6.230061  0.002893    1.839488               2
